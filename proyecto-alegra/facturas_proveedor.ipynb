# %%
import pandas as pd
import requests 
import os

# %%
url3 = "https://api.alegra.com/api/v1/bills?metadata=true&limit=30&order_direction=ASC&type=bill"

headers3= {
    "accept": "application/json",
    "authorization": "Basic bmFub3Ryb25pY3NhbHNvbmRlbGF0ZWNub2xvZ2lhQGdtYWlsLmNvbTphMmM4OTA3YjE1M2VmYTc0ODE5ZA=="
}

response3 = requests.get(url3, headers=headers3)
#ahora sabemos cuantas son las facturas de proveedor
final = response3.json()["metadata"]["total"]

# %%
ruta_carpeta = 'D:\Desktop\python\proyecto-alegra'
nombre_archivo = 'facturas_proveedor.csv'
archivos_en_carpeta = os.listdir(ruta_carpeta)


if nombre_archivo in archivos_en_carpeta:
    df2 = pd.read_csv(nombre_archivo)
    #para saber cual fue la ultima factura de proveedor
    inicio = df2.iloc[-1]['id']
    
else:
    ##si no existe el archivo empezamos de cero

    url4 = f"https://api.alegra.com/api/v1/bills?start={0}&order_field=date&type=bill"

    headers4 = {
        "accept": "application/json",
        "authorization": "Basic bmFub3Ryb25pY3NhbHNvbmRlbGF0ZWNub2xvZ2lhQGdtYWlsLmNvbTphMmM4OTA3YjE1M2VmYTc0ODE5ZA=="
    }

    response4 = requests.get(url4, headers=headers4)
    ##creamos el primer dataframe
    df2 = pd.DataFrame.from_dict(response4.json())
    inicio = df2.iloc[-1]['id']

# %%
df4 = df2.head(0)
for i in range(int(inicio),int(final),30):
    url4 = f"https://api.alegra.com/api/v1/bills?start={i}&order_field=date&type=bill"

    headers4 = {
        "accept": "application/json",
        "authorization": "Basic bmFub3Ryb25pY3NhbHNvbmRlbGF0ZWNub2xvZ2lhQGdtYWlsLmNvbTphMmM4OTA3YjE1M2VmYTc0ODE5ZA=="
    }

    response4 = requests.get(url4, headers=headers4)
    df3 = pd.DataFrame.from_dict(response4.json())
    #concatenamos dataframe hasta la ultima factura
    if not df3.empty:
        df4 = pd.concat([df4,df3])

# %%
#filtramos

columnas = ['id', 'fecha','nombre','cantidad','precio','total', 'totalFact','proveedor']
df9 = pd.DataFrame(columns=columnas)

for index, row in df4.iterrows():
    if 'items' in row['purchases']:  
        for i in range(len(row['purchases']['items'])):
            nueva_fila = {'id':row['purchases']['items'][i]['id'],'fecha':row['date']
                        ,'nombre':row['purchases']['items'][i]['name'],'precio':row['purchases']['items'][i]['price'],
                        'cantidad':row['purchases']['items'][i]['quantity'],'total':row['purchases']['items'][i]['total'],
                        'totalFact':row['total'],'proveedor':row['provider']['name']                     
                        } 
            a  = pd.DataFrame(nueva_fila,index=[0])
        
        # Añadir la fila transformada al DataFrame de destino
            df9 = pd.concat([df9,a])

# %%
df10 = df9[df9['nombre'] == 'PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD']

# %%
df10
# Out:
#      id       fecha                                            nombre
# 0  2589  2024-01-27  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD  \
# 0  2589  2024-01-30  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-02-01  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-02-17  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-02-25  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-03-06  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-03-16  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-03-22  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-05-06  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-05-20  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-06-19  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-06-24  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-07-06  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-07-13  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-07-22  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-07-24  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
# 0  2589  2024-07-30  PORTATIL LENOVO 15.6" CORE I3 12AVA +8GB+512 SSD
#
#   cantidad   precio    total totalFact                       proveedor
# 0        1  1299000  1299000   1299000     COLOMBIANA DE COMERCIO S.A.
# 0        1  1299000  1299000   1299000     COLOMBIANA DE COMERCIO S.A.
# 0        2  1299000  2598000   2598000     COLOMBIANA DE COMERCIO S.A.
# 0        1  1329000  1329000   1329000                         LEDACOM
# 0        2  1299000  2598000   2598000  MPS MAYORISTA DE COLOMBIA S.A.
# 0        2  1279000  2558000   3057800                         LEDACOM
# 0        1  1268500  1268500   1530100                         LEDACOM
# 0        2  1249800  2499600   2748600                         LEDACOM
# 0        1  1261000  1261000   3183717  MPS MAYORISTA DE COLOMBIA S.A.
# 0        1  1143517  1143517   1143517  MPS MAYORISTA DE COLOMBIA S.A.
# 0        1  1199000  1199000   1199000     COLOMBIANA DE COMERCIO S.A.
# 0        1  1199000  1199000   1199000     COLOMBIANA DE COMERCIO S.A.
# 0        2  1207040  2414080   3857630     COLOMBIANA DE COMERCIO S.A.
# 0        2  1189000  2378000   2732000                         LEDACOM
# 0        1  1175000  1175000   3065300                         LEDACOM
# 0        2  1175000  2350000   2365000                         LEDACOM
# 0        2  1175000  2350000   2520000                         LEDACOM

# %%
if nombre_archivo in archivos_en_carpeta:
    df10 = pd.read_csv(nombre_archivo)
    df10 = pd.concat([df10,df9])
    df10.to_csv(nombre_archivo, index=False)
else:
    df9.to_csv(nombre_archivo, index=False)
