# %%
import requests
import pandas as pd
import datetime
import os

ruta_carpeta = 'D:\Desktop\python\proyecto-alegra'
nombre_archivo = 'facturas.csv'
archivos_en_carpeta = os.listdir(ruta_carpeta)


if nombre_archivo in archivos_en_carpeta:
    df2 = pd.read_csv('facturas.csv')
    inicio = df2.iloc[-1]['id']
else:
    ##en esta celda se pide se ingrese una fecha desde la que se quiere tener las facturas
    
    fecha_inicial = input("ingrese la fecha desde la que quiere las facturas en formato yyyy-mm-dd ")
    url = f"https://api.alegra.com/api/v1/invoices?order_direction=ASC&date_afterOrNow={fecha_inicial}"

    headers = {
        "accept": "application/json",
        "authorization": "Basic bmFub3Ryb25pY3NhbHNvbmRlbGF0ZWNub2xvZ2lhQGdtYWlsLmNvbTphMmM4OTA3YjE1M2VmYTc0ODE5ZA=="
    }

    response = requests.get(url, headers=headers)
    df2 = pd.DataFrame.from_dict(response.json())
    inicio = df2.iloc[0]['id']

# %%
df2.head()
# Out:
#      id        date     dueDate             datetime observations anotation  \
# 0  1516  2023-01-02  2023-01-02  2023-01-02 19:49:29         None
# 1  1515  2023-01-02  2023-01-02  2023-01-02 19:46:32         None
# 2  1514  2023-01-02  2023-01-02  2023-01-02 19:27:25         None
# 3  1513  2023-01-02  2023-01-02  2023-01-02 19:22:36         None
# 4  1512  2023-01-02  2023-01-02  2023-01-02 19:02:38         None
#
#   termsConditions  status                                             client  \
# 0                  closed  {'id': '5', 'name': 'Consumidor final', 'ident...
# 1                  closed  {'id': '5', 'name': 'Consumidor final', 'ident...
# 2                  closed  {'id': '5', 'name': 'Consumidor final', 'ident...
# 3                  closed  {'id': '5', 'name': 'Consumidor final', 'ident...
# 4                  closed  {'id': '5', 'name': 'Consumidor final', 'ident...
#
#                                       numberTemplate  ...      type  \
# 0  {'id': '1', 'prefix': None, 'number': '1474', ...  ...  NATIONAL
# 1  {'id': '1', 'prefix': None, 'number': '1473', ...  ...  NATIONAL
# 2  {'id': '1', 'prefix': None, 'number': '1472', ...  ...  NATIONAL
# 3  {'id': '1', 'prefix': None, 'number': '1471', ...  ...  NATIONAL
# 4  {'id': '1', 'prefix': None, 'number': '1470', ...  ...  NATIONAL
#
#    operationType  paymentMethod  \
# 0       STANDARD           CASH
# 1       STANDARD           CASH
# 2       STANDARD           CASH
# 3       STANDARD           CASH
# 4       STANDARD           CASH
#
#                                       barCodeContent  \
# 0  NumFac: 1474\nFecFac: 20230102000000\nHorFac: ...
# 1  NumFac: 1473\nFecFac: 20230102000000\nHorFac: ...
# 2  NumFac: 1472\nFecFac: 20230102000000\nHorFac: ...
# 3  NumFac: 1471\nFecFac: 20230102000000\nHorFac: ...
# 4  NumFac: 1470\nFecFac: 20230102000000\nHorFac: ...
#
#                                               seller  priceList  \
# 0  {'id': '1', 'name': 'FABIAN', 'identification'...       None
# 1  {'id': '1', 'name': 'FABIAN', 'identification'...       None
# 2  {'id': '1', 'name': 'FABIAN', 'identification'...       None
# 3  {'id': '1', 'name': 'FABIAN', 'identification'...       None
# 4  {'id': '2', 'name': 'DANIELA', 'identification...       None
#
#                                             payments  \
# 0  [{'id': '1761', 'prefix': None, 'number': '154...
# 1  [{'id': '1760', 'prefix': None, 'number': '154...
# 2  [{'id': '1759', 'prefix': None, 'number': '154...
# 3  [{'id': '1758', 'prefix': None, 'number': '154...
# 4  [{'id': '1757', 'prefix': None, 'number': '154...
#
#                                                items costCenter  \
# 0  [{'name': 'REPUESTO', 'description': None, 'pr...       None
# 1  [{'name': 'CABLE  2X1 5 METROS', 'description'...       None
# 2  [{'name': 'PILA ALCALINA PANASONIC AA ', 'desc...       None
# 3  [{'name': 'CABLE GRABADORA ', 'description': N...       None
# 4  [{'name': 'DISCO ESTADO SOLIDO KINGSTON 480GB'...       None
#
#                                     printingTemplate
# 0  {'id': '1', 'name': 'Clásico', 'pageSize': 'le...
# 1  {'id': '1', 'name': 'Clásico', 'pageSize': 'le...
# 2  {'id': '1', 'name': 'Clásico', 'pageSize': 'le...
# 3  {'id': '1', 'name': 'Clásico', 'pageSize': 'le...
# 4  {'id': '1', 'name': 'Clásico', 'pageSize': 'le...
#
# [5 rows x 29 columns]

# %%
##en df2 ya tenemos cargada la primera factura de esa fecha que se encuentra en la variable inicio

current_date = datetime.date.today()

# Calculate the date of yesterday
yesterday = current_date - datetime.timedelta(days=3)

url2 = f"https://api.alegra.com/api/v1/invoices?date_afterOrNow={yesterday}"

headers2 = {
    "accept": "application/json",
    "authorization": "Basic bmFub3Ryb25pY3NhbHNvbmRlbGF0ZWNub2xvZ2lhQGdtYWlsLmNvbTphMmM4OTA3YjE1M2VmYTc0ODE5ZA=="
}

response2 = requests.get(url2, headers=headers2)
df4 = pd.DataFrame.from_dict(response2.json())
##y aqui en la variable "final" esta la identificacion de ultima factura del día de ayer

final = int(df4.iloc[0]['id'])

# %%
print(inicio,final)
# Out:
# 1516 27652

# %%
# ... existing code ...

# Preparamos una lista para acumular los DataFrames
dfs = []

for i in range(int(inicio), final, 30):
    url3 = f"https://api.alegra.com/api/v1/invoices?start={i}&order_direction=ASC&order_field=id"
    
    headers3 = {
        "accept": "application/json",
        "authorization": "Basic bmFub3Ryb25pY3NhbHNvbmRlbGF0ZWNub2xvZ2lhQGdtYWlsLmNvbTphMmM4OTA3YjE1M2VmYTc0ODE5ZA=="
    }

    response3 = requests.get(url3, headers=headers3)
    
    if response3.status_code == 200 and response3.text:
        data = response3.json()
        if data:  # Verificamos que haya datos
            dfs.append(pd.DataFrame(data))

# Concatenamos todos los DataFrames una sola vez al final
if dfs:
    df6 = pd.concat(dfs, ignore_index=True)
else:
    df6 = pd.DataFrame()  # DataFrame vacío si no hay datos

# ... existing code ...

# %%
df6.head(2)
# Out:
#      id        date     dueDate             datetime observations anotation  \
# 0  1517  2023-01-03  2023-01-03  2023-01-03 10:06:40         None
# 1  1518  2023-01-03  2023-01-03  2023-01-03 10:07:36         None
#
#   termsConditions  status                                             client  \
# 0                  closed  {'id': '5', 'name': 'Consumidor final', 'ident...
# 1                  closed  {'id': '5', 'name': 'Consumidor final', 'ident...
#
#                                       numberTemplate  ...  \
# 0  {'id': '1', 'prefix': None, 'number': '1475', ...  ...
# 1  {'id': '1', 'prefix': None, 'number': '1476', ...  ...
#
#                                               seller  priceList  \
# 0  {'id': '2', 'name': 'DANIELA', 'identification...       None
# 1  {'id': '2', 'name': 'DANIELA', 'identification...       None
#
#                                             payments  \
# 0  [{'id': '1762', 'prefix': None, 'number': '154...
# 1  [{'id': '1763', 'prefix': None, 'number': '154...
#
#                                                items  costCenter  \
# 0  [{'name': 'CABLE DE RED CAT6 5 MTS MTS-1042G-3...        None
# 1  [{'name': 'MEMORIA USB  16 GB DG', 'descriptio...        None
#
#                                     printingTemplate paymentForm stamp  \
# 0  {'id': '1', 'name': 'Clásico', 'pageSize': 'le...         NaN   NaN
# 1  {'id': '1', 'name': 'Clásico', 'pageSize': 'le...         NaN   NaN
#
#   retentions station
# 0        NaN     NaN
# 1        NaN     NaN
#
# [2 rows x 33 columns]

# %%
df8 = df6.drop(columns=['observations','payments','subtotal','barCodeContent','total','numberTemplate','dueDate','stamp','warehouse','term','anotation','termsConditions','status','priceList','costCenter','paymentForm','type','discount','tax','balance','decimalPrecision','operationType','printingTemplate','station'])

# %%
df8
# Out:
#           id        date             datetime  \
# 0       1517  2023-01-03  2023-01-03 10:06:40
# 1       1518  2023-01-03  2023-01-03 10:07:36
# 2       1519  2023-01-03  2023-01-03 10:22:53
# 3       1520  2023-01-03  2023-01-03 10:47:31
# 4       1521  2023-01-03  2023-01-03 11:13:43
# ...      ...         ...                  ...
# 26131  27648  2025-05-25  2025-05-25 18:44:07
# 26132  27649  2025-05-25  2025-05-25 18:45:15
# 26133  27650  2025-05-25  2025-05-25 19:01:49
# 26134  27651  2025-05-25  2025-05-25 19:04:41
# 26135  27652  2025-05-25  2025-05-25 19:10:42
#
#                                                   client  totalPaid  \
# 0      {'id': '5', 'name': 'Consumidor final', 'ident...      12000
# 1      {'id': '5', 'name': 'Consumidor final', 'ident...      25000
# 2      {'id': '87', 'name': 'PROACTIVA ESPECIALIZADA ...     140000
# 3      {'id': '5', 'name': 'Consumidor final', 'ident...       7000
# 4      {'id': '5', 'name': 'Consumidor final', 'ident...      48000
# ...                                                  ...        ...
# 26131  {'id': '5', 'name': 'Consumidor final', 'ident...     119000
# 26132  {'id': '5', 'name': 'Consumidor final', 'ident...      12000
# 26133  {'id': '5', 'name': 'Consumidor final', 'ident...      38000
# 26134  {'id': '5', 'name': 'Consumidor final', 'ident...      56000
# 26135  {'id': '5', 'name': 'Consumidor final', 'ident...      65000
#
#         paymentMethod                                             seller  \
# 0                CASH  {'id': '2', 'name': 'DANIELA', 'identification...
# 1                CASH  {'id': '2', 'name': 'DANIELA', 'identification...
# 2        BANK_DEPOSIT                                               None
# 3                CASH  {'id': '1', 'name': 'FABIAN', 'identification'...
# 4                CASH  {'id': '1', 'name': 'FABIAN', 'identification'...
# ...               ...                                                ...
# 26131  DEBIT_TRANSFER  {'id': '2', 'name': 'DANIELA', 'identification...
# 26132            CASH  {'id': '2', 'name': 'DANIELA', 'identification...
# 26133            CASH  {'id': '3', 'name': 'JUAN PABLO', 'identificat...
# 26134            CASH  {'id': '3', 'name': 'JUAN PABLO', 'identificat...
# 26135  DEBIT_TRANSFER  {'id': '3', 'name': 'JUAN PABLO', 'identificat...
#
#                                                    items retentions
# 0      [{'name': 'CABLE DE RED CAT6 5 MTS MTS-1042G-3...        NaN
# 1      [{'name': 'MEMORIA USB  16 GB DG', 'descriptio...        NaN
# 2      [{'name': 'LECTOR CODIGO DE BARRAS ', 'descrip...        NaN
# 3      [{'name': 'ADAPTADOR DE CARGA SENCILLO K-BLES'...        NaN
# 4      [{'name': 'ADAPTADOR 12V 2A', 'description': N...        NaN
# ...                                                  ...        ...
# 26131  [{'name': 'BATERIA PORTATIL 20000MAH 1HORA 20W...        NaN
# 26132  [{'name': 'CABLE TIPO C MOVISUN Z63UC', 'descr...        NaN
# 26133  [{'name': 'SISTEPAGOS', 'description': None, '...        NaN
# 26134  [{'name': 'CEPILLO SECADOR ONE STEP', 'descrip...        NaN
# 26135  [{'name': 'DIADEMA KG-100 MOVISUN', 'descripti...        NaN
#
# [26136 rows x 9 columns]

# %%
df8.head()
# Out:
#      id        date             datetime  \
# 0  1517  2023-01-03  2023-01-03 10:06:40
# 1  1518  2023-01-03  2023-01-03 10:07:36
# 2  1519  2023-01-03  2023-01-03 10:22:53
# 3  1520  2023-01-03  2023-01-03 10:47:31
# 4  1521  2023-01-03  2023-01-03 11:13:43
#
#                                               client  totalPaid paymentMethod  \
# 0  {'id': '5', 'name': 'Consumidor final', 'ident...      12000          CASH
# 1  {'id': '5', 'name': 'Consumidor final', 'ident...      25000          CASH
# 2  {'id': '87', 'name': 'PROACTIVA ESPECIALIZADA ...     140000  BANK_DEPOSIT
# 3  {'id': '5', 'name': 'Consumidor final', 'ident...       7000          CASH
# 4  {'id': '5', 'name': 'Consumidor final', 'ident...      48000          CASH
#
#                                               seller  \
# 0  {'id': '2', 'name': 'DANIELA', 'identification...
# 1  {'id': '2', 'name': 'DANIELA', 'identification...
# 2                                               None
# 3  {'id': '1', 'name': 'FABIAN', 'identification'...
# 4  {'id': '1', 'name': 'FABIAN', 'identification'...
#
#                                                items retentions
# 0  [{'name': 'CABLE DE RED CAT6 5 MTS MTS-1042G-3...        NaN
# 1  [{'name': 'MEMORIA USB  16 GB DG', 'descriptio...        NaN
# 2  [{'name': 'LECTOR CODIGO DE BARRAS ', 'descrip...        NaN
# 3  [{'name': 'ADAPTADOR DE CARGA SENCILLO K-BLES'...        NaN
# 4  [{'name': 'ADAPTADOR 12V 2A', 'description': N...        NaN

# %%
##solo dejamos en 'client' , 'seller' nombres y filtramos paymentMethod

def editar_factura(row):
    row['client'] = row['client']['name']
    if row['seller'] != None:
        row['seller'] = row['seller']['name']
    else:
        row['seller'] = 'No se ha registrado un vendedor'

    return row

    
df8=df8.apply(editar_factura, axis=1)
df8.head()
# Out:
#      id        date             datetime                         client  \
# 0  1517  2023-01-03  2023-01-03 10:06:40               Consumidor final
# 1  1518  2023-01-03  2023-01-03 10:07:36               Consumidor final
# 2  1519  2023-01-03  2023-01-03 10:22:53  PROACTIVA ESPECIALIZADA S.A.S
# 3  1520  2023-01-03  2023-01-03 10:47:31               Consumidor final
# 4  1521  2023-01-03  2023-01-03 11:13:43               Consumidor final
#
#    totalPaid paymentMethod                           seller  \
# 0      12000          CASH                          DANIELA
# 1      25000          CASH                          DANIELA
# 2     140000  BANK_DEPOSIT  No se ha registrado un vendedor
# 3       7000          CASH                           FABIAN
# 4      48000          CASH                           FABIAN
#
#                                                items retentions
# 0  [{'name': 'CABLE DE RED CAT6 5 MTS MTS-1042G-3...        NaN
# 1  [{'name': 'MEMORIA USB  16 GB DG', 'descriptio...        NaN
# 2  [{'name': 'LECTOR CODIGO DE BARRAS ', 'descrip...        NaN
# 3  [{'name': 'ADAPTADOR DE CARGA SENCILLO K-BLES'...        NaN
# 4  [{'name': 'ADAPTADOR 12V 2A', 'description': N...        NaN

# %%
df8.tail(10)
# Out:
#           id        date             datetime            client  totalPaid  \
# 26126  27643  2025-05-25  2025-05-25 17:01:01  Consumidor final      79000
# 26127  27644  2025-05-25  2025-05-25 17:12:31  Consumidor final      49000
# 26128  27645  2025-05-25  2025-05-25 17:14:48  Consumidor final      10000
# 26129  27646  2025-05-25  2025-05-25 18:12:14  Consumidor final      79000
# 26130  27647  2025-05-25  2025-05-25 18:16:20     SOLOGEM S.A.S     249000
# 26131  27648  2025-05-25  2025-05-25 18:44:07  Consumidor final     119000
# 26132  27649  2025-05-25  2025-05-25 18:45:15  Consumidor final      12000
# 26133  27650  2025-05-25  2025-05-25 19:01:49  Consumidor final      38000
# 26134  27651  2025-05-25  2025-05-25 19:04:41  Consumidor final      56000
# 26135  27652  2025-05-25  2025-05-25 19:10:42  Consumidor final      65000
#
#         paymentMethod      seller  \
# 26126            CASH      CAMILA
# 26127            CASH     DANIELA
# 26128            CASH  JUAN PABLO
# 26129      DEBIT_CARD     DANIELA
# 26130      DEBIT_CARD  JUAN PABLO
# 26131  DEBIT_TRANSFER     DANIELA
# 26132            CASH     DANIELA
# 26133            CASH  JUAN PABLO
# 26134            CASH  JUAN PABLO
# 26135  DEBIT_TRANSFER  JUAN PABLO
#
#                                                    items retentions
# 26126  [{'name': 'REGULADOR DE VOLTAJE UNITEC U-1200'...        NaN
# 26127  [{'name': 'AUDIFONOS BLUETOOTH TWS NEGRO AUT11...        NaN
# 26128  [{'name': 'CONVERTIDOR DE TIPO C A USB 3.0', '...        NaN
# 26129  [{'name': 'DIADEMA BLUETOOTH MOVISUN K20 GRIS'...        NaN
# 26130  [{'name': 'PARLANTE NIA AN-2042', 'description...        NaN
# 26131  [{'name': 'BATERIA PORTATIL 20000MAH 1HORA 20W...        NaN
# 26132  [{'name': 'CABLE TIPO C MOVISUN Z63UC', 'descr...        NaN
# 26133  [{'name': 'SISTEPAGOS', 'description': None, '...        NaN
# 26134  [{'name': 'CEPILLO SECADOR ONE STEP', 'descrip...        NaN
# 26135  [{'name': 'DIADEMA KG-100 MOVISUN', 'descripti...        NaN

# %% [markdown]
# pendientes:
# implementar los diccionarios como parte del dataframe

# %%
def eliminar_diccionario(row):
    for i in row['items']:
        del i['description']
        del i['discount']
        del i['productKey']
        del i['unit']
        del i['tax']
        del i['reference']
        del i['id']
    return row

df8=df8.apply(eliminar_diccionario, axis=1)
df8.head()
# Out:
#      id        date             datetime                         client  \
# 0  1517  2023-01-03  2023-01-03 10:06:40               Consumidor final
# 1  1518  2023-01-03  2023-01-03 10:07:36               Consumidor final
# 2  1519  2023-01-03  2023-01-03 10:22:53  PROACTIVA ESPECIALIZADA S.A.S
# 3  1520  2023-01-03  2023-01-03 10:47:31               Consumidor final
# 4  1521  2023-01-03  2023-01-03 11:13:43               Consumidor final
#
#    totalPaid paymentMethod                           seller  \
# 0      12000          CASH                          DANIELA
# 1      25000          CASH                          DANIELA
# 2     140000  BANK_DEPOSIT  No se ha registrado un vendedor
# 3       7000          CASH                           FABIAN
# 4      48000          CASH                           FABIAN
#
#                                                items retentions
# 0  [{'name': 'CABLE DE RED CAT6 5 MTS MTS-1042G-3...        NaN
# 1  [{'name': 'MEMORIA USB  16 GB DG', 'price': 25...        NaN
# 2  [{'name': 'LECTOR CODIGO DE BARRAS ', 'price':...        NaN
# 3  [{'name': 'ADAPTADOR DE CARGA SENCILLO K-BLES'...        NaN
# 4  [{'name': 'ADAPTADOR 12V 2A', 'price': 12000, ...        NaN

# %%
df8
# Out:
#           id        date             datetime                         client  \
# 0       1517  2023-01-03  2023-01-03 10:06:40               Consumidor final
# 1       1518  2023-01-03  2023-01-03 10:07:36               Consumidor final
# 2       1519  2023-01-03  2023-01-03 10:22:53  PROACTIVA ESPECIALIZADA S.A.S
# 3       1520  2023-01-03  2023-01-03 10:47:31               Consumidor final
# 4       1521  2023-01-03  2023-01-03 11:13:43               Consumidor final
# ...      ...         ...                  ...                            ...
# 26131  27648  2025-05-25  2025-05-25 18:44:07               Consumidor final
# 26132  27649  2025-05-25  2025-05-25 18:45:15               Consumidor final
# 26133  27650  2025-05-25  2025-05-25 19:01:49               Consumidor final
# 26134  27651  2025-05-25  2025-05-25 19:04:41               Consumidor final
# 26135  27652  2025-05-25  2025-05-25 19:10:42               Consumidor final
#
#        totalPaid   paymentMethod                           seller  \
# 0          12000            CASH                          DANIELA
# 1          25000            CASH                          DANIELA
# 2         140000    BANK_DEPOSIT  No se ha registrado un vendedor
# 3           7000            CASH                           FABIAN
# 4          48000            CASH                           FABIAN
# ...          ...             ...                              ...
# 26131     119000  DEBIT_TRANSFER                          DANIELA
# 26132      12000            CASH                          DANIELA
# 26133      38000            CASH                       JUAN PABLO
# 26134      56000            CASH                       JUAN PABLO
# 26135      65000  DEBIT_TRANSFER                       JUAN PABLO
#
#                                                    items retentions
# 0      [{'name': 'CABLE DE RED CAT6 5 MTS MTS-1042G-3...        NaN
# 1      [{'name': 'MEMORIA USB  16 GB DG', 'price': 25...        NaN
# 2      [{'name': 'LECTOR CODIGO DE BARRAS ', 'price':...        NaN
# 3      [{'name': 'ADAPTADOR DE CARGA SENCILLO K-BLES'...        NaN
# 4      [{'name': 'ADAPTADOR 12V 2A', 'price': 12000, ...        NaN
# ...                                                  ...        ...
# 26131  [{'name': 'BATERIA PORTATIL 20000MAH 1HORA 20W...        NaN
# 26132  [{'name': 'CABLE TIPO C MOVISUN Z63UC', 'price...        NaN
# 26133  [{'name': 'SISTEPAGOS', 'price': 38000, 'quant...        NaN
# 26134  [{'name': 'CEPILLO SECADOR ONE STEP', 'price':...        NaN
# 26135  [{'name': 'DIADEMA KG-100 MOVISUN', 'price': 6...        NaN
#
# [26136 rows x 9 columns]

# %%
columnas = ['id', 'fecha','hora','nombre','precio','cantidad','total','cliente', 'totalfact','metodo','vendedor']
df9 = pd.DataFrame(columns=columnas)

for index, row in df8.iterrows():   
    for i in range(len(row['items'])):
        nueva_fila = {'id':row['id'],'fecha':row['date'],'hora':row['datetime']
                      ,'nombre':row['items'][i]['name'],'precio':row['items'][i]['price'],
                      'cantidad':row['items'][i]['quantity'],'total':row['items'][i]['total'],
                      'cliente':row['client'],'totalfact':row['totalPaid'],'metodo':row['paymentMethod'],'vendedor':row['seller']                      
                      } 
        a  = pd.DataFrame(nueva_fila,index=[0])
    
    # Añadir la fila transformada al DataFrame de destino
        df9 = pd.concat([df9,a])

# %%
df9.head()
# Out:
#      id       fecha                 hora  \
# 0  1517  2023-01-03  2023-01-03 10:06:40
# 0  1518  2023-01-03  2023-01-03 10:07:36
# 0  1519  2023-01-03  2023-01-03 10:22:53
# 0  1520  2023-01-03  2023-01-03 10:47:31
# 0  1521  2023-01-03  2023-01-03 11:13:43
#
#                                  nombre  precio cantidad   total  \
# 0  CABLE DE RED CAT6 5 MTS MTS-1042G-3    12000        1   12000
# 0                 MEMORIA USB  16 GB DG   25000        1   25000
# 0              LECTOR CODIGO DE BARRAS   140000        1  140000
# 0    ADAPTADOR DE CARGA SENCILLO K-BLES    7000        1    7000
# 0                      ADAPTADOR 12V 2A   12000        4   48000
#
#                          cliente totalfact        metodo  \
# 0               Consumidor final     12000          CASH
# 0               Consumidor final     25000          CASH
# 0  PROACTIVA ESPECIALIZADA S.A.S    140000  BANK_DEPOSIT
# 0               Consumidor final      7000          CASH
# 0               Consumidor final     48000          CASH
#
#                           vendedor
# 0                          DANIELA
# 0                          DANIELA
# 0  No se ha registrado un vendedor
# 0                           FABIAN
# 0                           FABIAN

# %%
 if nombre_archivo in archivos_en_carpeta:
     df10 = pd.read_csv('facturas.csv')
     df10 = pd.concat([df10,df9])
     df10.to_csv("facturas.csv", index=False)
 else:
     df9.to_csv("facturas.csv", index=False)

# %%
df9.head()
# Out:
#      id       fecha                 hora  \
# 0  1517  2023-01-03  2023-01-03 10:06:40
# 0  1518  2023-01-03  2023-01-03 10:07:36
# 0  1519  2023-01-03  2023-01-03 10:22:53
# 0  1520  2023-01-03  2023-01-03 10:47:31
# 0  1521  2023-01-03  2023-01-03 11:13:43
#
#                                  nombre  precio cantidad   total  \
# 0  CABLE DE RED CAT6 5 MTS MTS-1042G-3    12000        1   12000
# 0                 MEMORIA USB  16 GB DG   25000        1   25000
# 0              LECTOR CODIGO DE BARRAS   140000        1  140000
# 0    ADAPTADOR DE CARGA SENCILLO K-BLES    7000        1    7000
# 0                      ADAPTADOR 12V 2A   12000        4   48000
#
#                          cliente totalfact        metodo  \
# 0               Consumidor final     12000          CASH
# 0               Consumidor final     25000          CASH
# 0  PROACTIVA ESPECIALIZADA S.A.S    140000  BANK_DEPOSIT
# 0               Consumidor final      7000          CASH
# 0               Consumidor final     48000          CASH
#
#                           vendedor
# 0                          DANIELA
# 0                          DANIELA
# 0  No se ha registrado un vendedor
# 0                           FABIAN
# 0                           FABIAN

# %%
from sqlalchemy import types as sa_types

engine = create_engine("postgresql+psycopg2://postgres:1234@localhost:5432/prueba_crm")

# Mapeo de tipos de columna
dtype_mapping = {
    'id': sa_types.INTEGER(),
    'fecha': sa_types.DATE(),
    'hora': sa_types.TIME(),
    'nombre': sa_types.String(length = 100),
    'precio': sa_types.FLOAT(),
    'cantidad': sa_types.INTEGER(),
    'total': sa_types.INTEGER(),
    'cliente': sa_types.String(length = 100),
    'totalfact': sa_types.FLOAT(),
    'metodo': sa_types.String(length = 100),
    'vendedor': sa_types.String(length = 100)
    # Añade el resto de columnas según corresponda
}

# Insertar especificando tipos
df9.to_sql(
    "facturas",
    engine,
    if_exists="append",
    index=False,
    dtype=dtype_mapping

)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 from sqlalchemy import types as sa_types
# ----> 3 engine = create_engine("postgresql+psycopg2://postgres:1234@localhost:5432/prueba_crm")
#       5 # Mapeo de tipos de columna
#       6 dtype_mapping = {
#       7     'id': sa_types.INTEGER(),
#       8     'fecha': sa_types.DATE(),
#    (...)
#      18     # Añade el resto de columnas según corresponda
#      19 }
#
# NameError: name 'create_engine' is not defined

# %%
# Consulta básica
query = "SELECT * FROM facturas WHERE indx = 73"
df = pd.read_sql(query, engine)
print(df.head())
# Out:
#    indx       fecha                hora                         nombre
# 0    73  2025-04-13 2025-04-13 18:27:07  REPETIDOR TP-LINK AC750 RE202  \
#
#    precio  cantidad  total           cliente  totalfact metodo vendedor     id
# 0   99000         1  99000  Consumidor final      99000   CASH  DANIELA  26376
